# %% [markdown]
# # **多层感知机**

# %% [markdown]
# ### **单隐藏层**

# %% [markdown]
# 隐藏层的大小是超参数

# %% [markdown]
# ### **Sigmoid激活函数**

# %% [markdown]
# 将输入投影到(0,1)的一个软的ρ(x)函数

# %% [markdown]
# $
# sigmoid(x)=\frac{1}{1+e^{-x}}
# $

# %%
import math  
import numpy as np  
import matplotlib.pyplot as plt  

x = np.arange(-8, 8, 0.1 )  
e = math.e  
sigmoid = 1 / (1 + e ** (-x))  

plt.title("Sigmoid激活函数")  
plt.plot(x , sigmoid)  
plt.show()

# %% [markdown]
# ### **Tanh激活函数**

# %% [markdown]
# 将输入投影到(-1,1)  $
# tanh(x)=\frac{1-e^{-2x}}{1+e^{-2x}}
# $

# %%
x = np.arange(-8, 8, 0.1 )  
e = math.e  
tanh = (1 - e ** (-2*x)) / (1 + e ** (-2*x))  

plt.title("tanh激活函数")  
plt.plot(x , tanh)  
plt.show()

# %% [markdown]
# ### **ReLU激活函数**

# %% [markdown]
# $
# ReLU(x)=\max(x,0)
# $

# %%
x = np.arange(-8, 8, 0.1 )   
ReLU = np.maximum(x, 0)  

plt.title("ReLU激活函数")  
plt.plot(x , ReLU)  
plt.show()

# %% [markdown]
# ### **多类分类**

# %% [markdown]
# $y_1,y_2,...,y_k=softmax(o_1,o_2,...,o_k)$

# %% [markdown]
# > Softmax将所有的输入拉到[0, 1]之间，使得$y_1+y_2+...+y_k=1$

# %% [markdown]
# 如果往Softmax回归中加入**隐藏层**，就变为了**多层感知机**。

# %% [markdown]
# ### **多隐藏层**

# %% [markdown]
# $h_1=\sigma(W_1x+b_1)\\
# h_2=\sigma(W_2h_1+b_2)\\
# h_3=\sigma(W_3h_2+b_3)\\
# o=W_1h_3+b_4$

# %% [markdown]
# **超参数**：
# * 隐藏层数
# * 每层隐藏层大小

# %% [markdown]
# ### **总结**

# %% [markdown]
# * 多层感知机使用隐藏层和激活函数(非线性函数)来得到非线性模型
# * 常用激活函数是Sigmoid，Tanh，ReLU
# * 使用Softmax来处理多分类
# * 超参数为隐藏层数和各个隐藏层大小
